# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Reading Data

# %%
data=pd.read_csv("C:\\Users\\HP\\Desktop\\New folder (3)\\train.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# Handling Missing Value

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data['Age']=data['Age'].fillna(data['Age'].mean())
data['Cabin']=data['Cabin'].fillna(data['Cabin'].mode()[0])
data['Embarked']=data['Embarked'].fillna(data['Embarked'].mode()[0])

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked
# 0      0         A/5 21171   7.2500  B96 B98        S
# 1      0          PC 17599  71.2833      C85        C
# 2      0  STON/O2. 3101282   7.9250  B96 B98        S
# 3      0            113803  53.1000     C123        S
# ...

# %%
plt.figure(figsize=(6,4))
plt.hist(data['Age'])
plt.title('Histogram of Age')
# Out:
# Text(0.5, 1.0, 'Histogram of Age')

# %%
plt.figure(figsize=(2,10))
sns.displot(data['Age'])
plt.title("Age")
# Out:
# Text(0.5, 1.0, 'Age')

# %%
plt.figure(figsize=(6,4))
sns.relplot(x="Age",y="Fare",col="Survived",kind="line",hue="Sex",data=data)

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x="Age",y="Fare",hue="Pclass",data=data)
plt.title("Age and Fare in Different Class")
# Out:
# Text(0.5, 1.0, 'Age and Fare in Different Class')

# %%
plt.figure(figsize=(6,4))
sns.set_palette("Paired")
sns.barplot(x="Sex",y="Survived",hue="Pclass",data=data)
plt.title("Survived by Sex and Class")
# Out:
# Text(0.5, 1.0, 'Survived by Sex and Class')

# %%
plt.figure(figsize=(6,4))
sns.set_palette("Paired")
sns.stripplot(x="Sex",y="Age",data=data)
plt.title("Age by Sex")
# Out:
# Text(0.5, 1.0, 'Age by Sex')

# %%
plt.figure(figsize=(6,4))
sns.swarmplot(x="Sex",y="Age",data=data)
plt.title("Age by Sex")
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3540: UserWarning: 18.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3540: UserWarning: 7.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Age by Sex')
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3540: UserWarning: 26.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x="Survived",y="Age",data=data)
plt.title("Age by Survived")
# Out:
# Text(0.5, 1.0, 'Age by Survived')

# %%
plt.figure(figsize=(6,4))
sns.violinplot(x="Survived",y="Age",hue="Sex",data=data)
plt.title("Age by Sex and Survived")
# Out:
# Text(0.5, 1.0, 'Age by Sex and Survived')

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Survived",data=data)
plt.title("Survived")
# Out:
# Text(0.5, 1.0, 'Survived')

# %%
plt.figure(figsize=(6,4))
sns.pointplot(x="Sex",y="Survived",hue="Pclass",data=data)
# Out:
# <AxesSubplot: xlabel='Sex', ylabel='Survived'>

# %%
plt.figure(figsize=(6,4))
sns.regplot(x="Age",y="Fare",data=data)
plt.title("Fare and Age")
# Out:
# Text(0.5, 1.0, 'Fare and Age')

# %%
df=data[["Pclass","SibSp","Parch"]]
Survived=data["Survived"]
sns.clustermap(df,dendrogram_ratio=(.1,.2),cbar_pos=(0,.2,.03,.4))

# %%
plt.figure(figsize=(6,4))
sns.set_style("ticks")
sns.pairplot(data, hue='Sex', diag_kind="hist", kind="scatter", palette="husl")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.PairGrid(data).map(plt.scatter)

# %%
plt.figure(figsize=(6,4))
g = sns.PairGrid(data)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)
g.map_diag(sns.countplot);
plt.show()

# %% [markdown]
# Handling Categorical Data

# %%
sexmap={"male":1,"female":0}
data['Sex']=data['Sex'].map(sexmap)

# %%
data.groupby('Sex').nunique()
# Out:
#      PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# 0            314         2       3   314   64      7      7     247   156
# 1            577         2       3   577   83      7      6     519   193
#
#      Cabin  Embarked
# Sex
# 0       75         3
# 1       96         3

# %%
emmap={"C":1,"Q":2,"S":3}
data['Embarked']=data['Embarked'].map(emmap)

# %%
data.groupby('Embarked').nunique()
# Out:
#           PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  \
# Embarked
# 1                 168         2       3   168    2   59      3      4     122
# 2                  77         2       3    77    2   25      4      4      66
# 3                 646         2       3   646    2   81      7      7     495
#
#           Fare  Cabin
# Embarked
# 1           74     58
# 2           22      4
# 3          164     90

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare    Cabin  Embarked
# 0         A/5 21171   7.2500  B96 B98         3
# 1          PC 17599  71.2833      C85         1
# 2  STON/O2. 3101282   7.9250  B96 B98         3
# 3            113803  53.1000     C123         3
# 4            373450   8.0500  B96 B98         3

# %%
data.drop(["PassengerId","Name","Ticket","Cabin"],axis=1,inplace=True)

# %%
data.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    1  22.0      1      0   7.2500         3
# 1         1       1    0  38.0      1      0  71.2833         1
# 2         1       3    0  26.0      0      0   7.9250         3
# 3         1       1    0  35.0      1      0  53.1000         3
# 4         0       3    1  35.0      0      0   8.0500         3

# %%
cor=data.corr()

# %%
fig,ax = plt.subplots(figsize=(8,4))
sns.heatmap(cor,annot=True,cmap="Blues")
plt.title("Heatmap")
# Out:
# Text(0.5, 1.0, 'Heatmap')
